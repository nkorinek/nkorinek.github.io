# %%
# YOUR CODE HERE
import hvplot.pandas
import pandas as pd

import warnings

warnings.filterwarnings('ignore')

# %%
# YOUR CODE HERE
NCEI_clim_data = 'https://www.ncei.noaa.gov/access/monitoring/'\
                 'climate-at-a-glance/city/time-series/USW00023174/'\
                 'tavg/12/12/1945-2022.csv'

# %%
# YOUR CODE HERE
climate_df = pd.read_csv(NCEI_clim_data,
                         header=3,
                         names=['year', 'temperature_f'])

# %%
# YOUR CODE HERE
climate_df.year = pd.to_datetime(climate_df.year, format='%Y%m').dt.year

# %%
# YOUR CODE HERE
def convert(temperature):
    """Convert temperature to Celcius"""
    return (temperature - 32) * 5 / 9


climate_df['temperature_c'] = climate_df['temperature_f'].apply(convert)

# %% [markdown]
# # This is an analysis wow

# %%
# YOUR CODE HERE
climate_df.plot(x='year', y='temperature_c', title="Maximum annual temperature in Los Angeles, CA from 1949 to 2022", ylabel="Temperature (C)", xlabel="Year")
# Out:
# <Axes: title={'center': 'Maximum annual temperature in Los Angeles, CA from 1949 to 2022'}, xlabel='Year', ylabel='Temperature (C)'>

# %%
# %%capture
# %%bash
jupyter nbconvert test_book.ipynb --to html --no-input
